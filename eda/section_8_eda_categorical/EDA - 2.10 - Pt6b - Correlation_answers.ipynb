# %% [markdown]
# ## Correlation
# In this notebook we'll look at
# 1. Calculating correlation
# 2. Visualising correlation

# %% [markdown]
# ### Load data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing

raw_data = fetch_california_housing()
df = pd.DataFrame(data=raw_data['data'], columns=raw_data['feature_names'])
df['target'] = raw_data['target']
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df.shape
# Out:
# (20640, 9)

# %% [markdown]
# ## Pandas correlation

# %%
corr = df.corr()
corr
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# target      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    target
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# Population -0.108785   0.099773 -0.024650
# AveOccup    0.002366   0.002476 -0.023737
# Latitude    1.000000  -0.924664 -0.144160
# Longitude  -0.924664   1.000000 -0.045967
# target     -0.144160  -0.045967  1.000000

# %%
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col1 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col2 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col3 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col4 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col5 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col6 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row0_col8 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col0 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col2 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col3 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col4 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col5 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col6 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col7 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row1_col8 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col0 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col1 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col3 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col4 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col5 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col6 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col7 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row2_col8 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col0 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col1 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col2 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col4 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col5 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col6 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col7 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row3_col8 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col0 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col1 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col2 {
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col3 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col5 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col6 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col7 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row4_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col0 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col1 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col2 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col3 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col4 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col6 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col7 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row5_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col1 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col2 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col3 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col4 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_efee7c52_920b_11ea_a461_88e9fe6875c9row6_col5 {
#             background-color:  #d8dce2;
#             color:  #000000;

# %% [markdown]
# ## Seaborn
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
_ = sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap='coolwarm', annot=True)

# %%
_ = sns.pairplot(df[['MedInc', 'target', 'HouseAge', 'AveRooms']])
